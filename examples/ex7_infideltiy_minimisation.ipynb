# %%
# jVMC
import jVMC
import jVMC.nets as nets
import jVMC.operator as op
import jVMC.sampler
from jVMC.vqs import NQS

# jax
import jax
import jax.numpy as jnp
import jax.random as random

import numpy as np

# optimisation
import optax

# plotting
import matplotlib.pyplot as plt

# %% [markdown]
# # Minimising the infidelity for a trial model and a given target model
#
# ## First create the reference ground state
# We define a transverse field ising hamiltonian.

# %%
# create the transvere field Ising model Hamiltonian
sz = np.array([[1,0],[0,-1]])
sx = np.array([[0,1],[1,0]])

def tm(pm,i,N):
    if i == 0:
        re_ma = np.kron(pm,np.identity(2**(N-1)))
    else: re_ma = np.kron(np.identity(2**i),np.kron(pm,np.identity(2**(N-i-1))))
    return re_ma

#now we change H
def create_H(g,J,N):
  H_1 = tm(sx,0,N)
  for i in range(1,N): H_1 += tm(sx,i,N)

  H_0 = tm(sz,0,N).dot(tm(sz,1,N))+tm(sz,N-1,N).dot(tm(sz,0,N))
  for i in range(1,N-1): H_0 += tm(sz,i,N).dot(tm(sz,i+1,N))
  return -0.5*(g*H_1-J*H_0)

# %%
#############
# define the exact system
#############
 # sysetm parameters
L = 6
Ns = 2**L
# plot the ground state
#v,w = np.linalg.eigh(create_H(.01,1.,N))
J = 1.
g = 0.5
v,w = np.linalg.eigh(create_H(g,J,L))
gs = abs(w[:,0])
# getting the position of the Neel states
sigma = np.arange(2**L)[abs(gs)>0.1] # get peaked states
# plot
figure = plt.figure(dpi=100)
plt.plot(abs(gs))
plt.xlabel("state s")
plt.ylabel("$|\\psi(s)|$")
print(v[0])
# Out:
# -3.192347281801841

# %%
# set the wave function as target
chi_model = nets.Target(L=L,d=2)
# initialize the target model
chi = NQS(chi_model)
print("Net init: ",chi(jnp.array(jnp.ones((1, 1, L)))))
# setting the parameters
chi.set_parameters(jnp.array(gs))
# Out:
# Net init:  [[0.]]

# %% [markdown]
# ## Infidelity
#
# The infidelity for two pure states is defined as
# $$
# \mathcal{I} = 1 - \sum_s \Psi(s)\frac{\chi(s)}{\psi(s)}\times\sum_{s'} \Chi(s')\frac{\psi(s')}{\chi(s')} = 1 - \mathbb{E}_\Psi\frac{\chi(s)}{\psi(s)}\times\mathbb{E}_\Chi\frac{\psi(s')}{\chi(s')}
# $$
# where we have introduced the short-hand for the Born distribution for the target and trial wave function
# $$
# \Psi(s) = \frac{\psi(s)}{\sum_s|\psi(s)|^2} \qquad \Chi(s') = \frac{\chi(s')}{\sum_{s'}|\chi(s')|^2}
# $$
# With the local infidelity
# $$
# F^\psi_{\rm loc}(s) = \frac{\chi(s)}{\psi(s)}\times\sum_{s'} \qquad F^\chi_{\rm loc}(s') = \frac{\psi(s')}{\chi(s')}
# $$
# the infidelity can be expressed as
# $$
# \mathcal{I} = 1 - \mathbb{E}_\Psi F^\psi_{\rm loc}(s)\times\mathbb{E}_\Chi F^\chi_{\rm loc}(s')
# $$
# The derivative is
# $$
# 2\mathbb{E}_\Psi\big[ \Re~ O_k(s)F^\psi_{\rm loc}(s)\big] \, F^\chi-2\mathbb{E}_\Psi\big[ \Re~ O_k(\sigma)\big] \, F^\psi \, F^\chi
# $$

# %%
rbm = nets.CpxRBM(numHidden=6, bias=True) # get variational model
psi = NQS(rbm) # initialize variational model
psi(np.ones((1, 1, L)))
# Out:
# Array([[-0.000815+0.00629523j]], dtype=complex128)

# %%
n_iter = 100 # number of optimisation iterations
s_infidelity_acc = np.zeros(n_iter)

# %%
learning_rate=1e-2
# create the optimizer
optimizer = optax.adabelief(learning_rate=learning_rate)
# init optimizer
state = optimizer.init(psi.get_parameters())# test the compactified class

# %%
# set up sampler for the target
chiSampler = jVMC.sampler.MCSampler(chi, (L,), random.PRNGKey(np.random.randint(1000000)), updateProposer=jVMC.sampler.propose_spin_flip_Z2,
                                    numChains=20, sweepSteps=L,
                                    numSamples=1000, thermalizationSweeps=25)
# set up the infidelity
myInf = op.Infidelity(chiSampler=chiSampler,chi=chi)

# %%
for i in range(n_iter):
    if i%10 == 0: print("Iteration %i"%(i))
    # Set up sampler for psi
    psiSampler = jVMC.sampler.MCSampler(psi, (L,), random.PRNGKey(np.random.randint(1000000)), updateProposer=jVMC.sampler.propose_spin_flip_Z2,
                                    numChains=20, sweepSteps=L,
                                    numSamples=100, thermalizationSweeps=25)
    ######## get infidelity ########
    chi_Floc, Exp_chi_Floc = myInf.get_FP_loc(psi)
    psi_s, psi_logPsi, psi_p = psiSampler.sample()
    _, _ = myInf.get_s_primes(psi_s)
    psi_Floc = myInf.get_O_loc_unbatched(psi_logPsi)
    I_mean = jVMC.mpi_wrapper.global_mean(psi_Floc,psi_p)
    s_infidelity_acc[i] = I_mean.real
    print("Infidelity: %.6f"%(I_mean.real))

    # get the gradients
    grad = myInf.get_gradient(psi,psi_p)

    # get the psi parameters
    psi_params = psi.get_parameters()

    # update optimiser state
    updates, state = optimizer.update(grad.reshape(psi_params.shape), state, psi_params)  # Update para?meters
    params = optax.apply_updates(psi_params, updates)
    # set paramters again
    psi.set_parameters(params)
# Out:
# Iteration 0
# Infidelity: 0.915538
# Infidelity: 0.899427
# Infidelity: 0.851815
# Infidelity: 0.879792
# Infidelity: 0.828979
# Infidelity: 0.865970
# Infidelity: 0.873272
# Infidelity: 0.798046
# Infidelity: 0.790492
# Infidelity: 0.799383
# Iteration 10
# Infidelity: 0.663856
# Infidelity: 0.549867
# Infidelity: 0.563585
# Infidelity: 0.516389
# Infidelity: 0.372951
# Infidelity: 0.223160
# Infidelity: 0.300897
# Infidelity: 0.121000
# Infidelity: 0.084815
# Infidelity: 0.136209
# Iteration 20
# Infidelity: 0.099224
# Infidelity: 0.109002
# Infidelity: 0.106946
# Infidelity: 0.106025
# Infidelity: 0.089994
# Infidelity: 0.088817
# Infidelity: 0.095216
# Infidelity: 0.110426
# Infidelity: 0.103693
# Infidelity: 0.084160
# Iteration 30
# Infidelity: 0.072237
# Infidelity: 0.046036
# Infidelity: 0.065073
# Infidelity: 0.043744
# Infidelity: 0.048002
# Infidelity: 0.003990
# Infidelity: 0.063626
# Infidelity: 0.016652
# Infidelity: 0.072274
# Infidelity: 0.029844
# Iteration 40
# Infidelity: 0.047105
# Infidelity: 0.027742
# Infidelity: 0.058367
# Infidelity: 0.079100
# Infidelity: 0.057254
# Infidelity: 0.074783
# Infidelity: 0.048662
# Infidelity: 0.091849
# Infidelity: 0.053028
# Infidelity: 0.048563
# Iteration 50
# Infidelity: 0.059519
# Infidelity: 0.070725
# Infidelity: 0.066912
# Infidelity: 0.060743
# Infidelity: 0.064017
# Infidelity: -0.013463
# Infidelity: 0.055432
# Infidelity: 0.056140
# Infidelity: 0.006595
# Infidelity: 0.055285
# Iteration 60
# Infidelity: 0.032399
# Infidelity: 0.062155
# Infidelity: 0.043315
# Infidelity: 0.041572
# Infidelity: -0.032457
# Infidelity: 0.034480
# Infidelity: 0.010821
# Infidelity: 0.034004
# Infidelity: 0.041124
# Infidelity: 0.042899
# Iteration 70
# Infidelity: 0.013082
# Infidelity: -0.009909
# Infidelity: 0.031218
# Infidelity: -0.021003
# Infidelity: 0.009208
# Infidelity: 0.015968
# Infidelity: 0.003373
# Infidelity: 0.014875
# Infidelity: 0.022550
# Infidelity: 0.020916
# Iteration 80
# Infidelity: 0.017282
# Infidelity: 0.008123
# Infidelity: 0.011853
# Infidelity: 0.003376
# Infidelity: -0.002336
# Infidelity: 0.014067
# Infidelity: 0.010751
# Infidelity: 0.003948
# Infidelity: 0.002623
# Infidelity: 0.007796
# Iteration 90
# Infidelity: -0.004437
# Infidelity: 0.001855
# Infidelity: 0.002771
# Infidelity: -0.000077
# Infidelity: 0.001284
# Infidelity: 0.022570
# Infidelity: 0.003811
# Infidelity: 0.003691
# Infidelity: -0.006609
# Infidelity: 0.003130

# %%
plt.plot(jnp.arange(n_iter),abs(s_infidelity_acc))
plt.yscale("log")
plt.xlabel("iter")
plt.ylabel("$\\mathcal{I}$")
# Out:
# Text(0, 0.5, '$\\mathcal{I}$')
